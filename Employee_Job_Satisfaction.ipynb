# %% [markdown]
# Dan Doan <br>
# 01/30/2025

# %% [markdown]
# <b><u>Milestone 1 </u></b>
# <br>
# It is time to start using what you have learned throughout the first half of this course by developing an original data mining project. This week you will develop the project idea and do some data exploration/graphical analysis. You will continue working on and updating this project for the remainder of the term.
#
# The first step is coming up with an idea – arguably one of the hardest steps! Identify an original business problem for your project that can be solved with an appropriate model. By a business problem, it is meant that you should work on a problem where there is a good reason to solve it. There should be some organization or company that would find the solution to the problem useful. There are lots of ideas available online through Kaggle and other sources, but your idea should have a unique spin on it. The second step is locating your data. This can come from a variety of sources, e.g., Kaggle, your job, a website, API, etc. Feel free to reach out to your instructor if you are not sure if your idea and data are suitable. You may need to adjust your idea on the availability of data.
# <b>Begin Milestone 1 with a 250-500-word narrative describing your original idea for the analysis/model building business problem. Clearly identify the problem you will address and the target for your model.</b> Then, <b>do a graphical analysis creating a minimum of four graphs. Label your graphs appropriately and explain/analyze</b> the information provided by each graph. Your analysis should begin to answer the question(s) you are addressing. <b>Write a short overview/conclusion of the insights gained from your graphical analysis.</b>
# As a reminder, Teams is a great place to discuss your project with your peers. Feel free to solicit feedback/input (without creating a group project!) and collaborate on your projects with your peers. Each milestone will build on top of each other, so make sure you do not fall behind.
#
# I recommend building your project milestones in a Jupyter Notebook, building upon one another.

# %% [markdown]
# 1. <b>Begin Milestone 1 with a 250-500-word narrative describing your original idea for the analysis/model building business problem. Clearly identify the problem you will address and the target for your model. </b> <br>
# _____________________________________________________________________________________________________

# %% [markdown]
#         What contributes to the disruption of an employee’s livelihood where it leads to wanting to leave from their respective role within their own company?  I think this question is where all businesses would like to have or at the very least want to have better insights into this.
#
#         It is fairly common in the job market throughout various sectors of the economy that companies experience high employee turnover rates.  The most common reasons for an employee feeling very dissatisfied with where they want to leave or resigned are lack of career development, unsatisfactory comprehensive compensation, unfit work culture environment, and/or lack of engagement within the company. I am curious to see whether one’s lifestyle has an effect on them wanting to leave from their job. I don’t see unhappiness as a main factor to where it comes from since people can experience burnout from their jobs due to mental health issues. It wouldn’t make sense to overwork your employees if employers are already providing sick leave or vacation time off.
#
#         I was able to reference my data on the site using Kaggle by IBM data scientists to Employee Attrition & Performance. I will be looking at this dataset for my assessment in which consists of 35 columns. However, the column I will be targeting for my measurement is the “Job Satisfaction” column. I can use various regression and/or classification models to look for relationships or patterns for my analysis. I will want to look for any correlations that can help me lead to my findings such as scatterplot or the like.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#pd.set_option('display.max_rows', 1500)
pd.set_option('display.max_columns', None)

# %%
# https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset?resource=download
df = pd.read_csv('/Users/dandoan/Jupyter Notebook/DSC550/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# 2. Then, <b>do a graphical analysis creating a minimum of four graphs. Label your graphs appropriately and explain/analyze </b>the information provided by each graph.

# %%
# First Graph: Pie Chart

df_businesstravel_count= df['BusinessTravel'].value_counts()


df_businesstravel_count.plot(kind='pie', autopct='%1.1f%%')
plt.title('Business Travel Pie Chart')
plt.ylabel('')
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# The graph explains that majority of the employees in the dataset travels very rarely. This means that over the majority of the employees does not travel outside for work other than for vacation.

# %%
# Second Graph: Scatter Plot

df.plot(kind = 'scatter', x = 'Age', y = 'YearsAtCompany')


plt.title("Scatter Plot of Age vs #'s Years at Company")
plt.show()

# %% [markdown]
# This scatter plot shows a weak positive correlation between the employees' age and the number of years they stay at a company. If we were to remove the rest of the outside data points of the direct linear line then there seems to be a linear relationship when it comes to an employee's age with respect to the number of years they stay at a company.

# %%
# Third Graph: Line Plot

df_EmployeeNumber = df['EmployeeNumber']


plt.plot(df_EmployeeNumber)
plt.title('Line Plot of Employee(s)')
plt.xlabel("data point (x)")
plt.ylabel("#'s of employee(s)")
plt.show()

# %% [markdown]
# This line plot illustrate that the datasets contains the number of employees in ascending order.

# %%
# Fourth Graph: another Pie Chart

df_maritalstatus_count= df['MaritalStatus'].value_counts()


df_maritalstatus_count.plot(kind='pie', autopct='%1.1f%%')
plt.title('Marital Status Pie Chart')
plt.ylabel('')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# This bar chart shows the employee's marital status distribution for the given dataset. This tells me that each employee has at least one relationship other than being marital.

# %%
# Fifth Graph: another Pie Chart

df_attrition_count= df['Attrition'].value_counts()


df_attrition_count.plot(kind='pie', autopct='%1.1f%%')
plt.title('Attrition Pie Chart')
plt.ylabel('')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 3. <b>Write a short overview/conclusion of the insights gained from your graphical analysis.</b>

# %% [markdown]
# The graphs provides me better insight and clarity to the answers I am looking for. Initally I was looking for other factors that has an overall effect on job satisfaction however it seems to be more than the job itself. I have conclude to be led to believe that there are other personal relationship(s) other than marital that determine whether they would not want to be in their current role at a company. In other words, employees won't be content with the job if their personal relationship outside of the work itself doesn't align with their overall mental well being.

# %% [markdown]
# <b><u>Milestone 2</u></b>
# <br>
# Now that you have created your idea, located data, and have started your graphical analysis, you will move on to the <b>data preparation process</b> of your project. After completing Milestone 2, your data should be ready for the model building/evaluation phase.
# <br>
#
# Here is a list of steps to consider performing in Milestone 2:
# <br>
# - Drop any features that are not useful for your model building and explain why they are not useful.
# - Perform any data extraction/selection steps.
# - Transform features if necessary.
# - Engineer new useful features.
# - Deal with missing data (do not just drop rows or columns without justifying this).
# - Create dummy variables if necessary.
# <br>
#
# Explain your process at each step. You can use any methods/tools you think are most appropriate. Do what makes the most sense for your data/problem. This will vary greatly among different projects. Be careful to avoid data snooping in these steps.
# It is important to note that these milestones are meant to keep you on track for the final project submission. At any point, you can pivot or modify your project as needed based on what you discover. These milestones are not final versions; they are drafts of the many steps you need to complete along the way.
# As a reminder, Teams is a great place to discuss your project with your peers. Feel free to solicit feedback/input (without creating a group project!) and collaborate on your projects with your peers.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'binned'],
#       dtype='object')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# check for any null values
contains_na = df.isnull().values.any()

print(contains_na)
# Out:
# False

# %%
# -First step: Drop any features that are not useful for your model building and explain why they are not useful
#  a. Department: not relevant to the target variable
#  b. DistanceFromHome: not relevant with the assumption that the job is within close proximity
#  c. EmployeeCount: it is not related to the target variable
#  d. MonthlyRate: this information wouldn't be useful with respect to hourly wages and monthly income  
#  e. Over18:  this column is not necessary since there is already a column for age separately 
#  f. StandardHours: the number is simply arbitrary 
#  g. StockOptionLevel: this isn't useful if their company is listed on the stock market
#  h. TrainingTimesLastYear: I prefer to look at the Education column or EducationField column 

df_modified = df.drop(['Department', 'DistanceFromHome', 'EmployeeCount', 'MonthlyRate', 'Over18', 
                       'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear'], axis=1)


df_modified
# Out:
#       Age Attrition     BusinessTravel  DailyRate  Education EducationField  \
# 0      41       Yes      Travel_Rarely       1102          2  Life Sciences
# 1      49        No  Travel_Frequently        279          1  Life Sciences
# 2      37       Yes      Travel_Rarely       1373          2          Other
# 3      33        No  Travel_Frequently       1392          4  Life Sciences
# 4      27        No      Travel_Rarely        591          1        Medical
# ...   ...       ...                ...        ...        ...            ...
# 1465   36        No  Travel_Frequently        884          2        Medical
# 1466   39        No      Travel_Rarely        613          1        Medical
# 1467   27        No      Travel_Rarely        155          3  Life Sciences
# 1468   49        No  Travel_Frequently       1023          3        Medical
# 1469   34        No      Travel_Rarely        628          3        Medical
#
# ...

# %%
# -Second step: Convert the categorical columns to dummy variables 

df_modified_2 = df_modified
df_modified_2_with_dummies = pd.get_dummies(df_modified_2, drop_first=True) 

df_modified_2_with_dummies
# Out:
#       Age  DailyRate  Education  EmployeeNumber  EnvironmentSatisfaction  \
# 0      41       1102          2               1                        2
# 1      49        279          1               2                        3
# 2      37       1373          2               4                        4
# 3      33       1392          4               5                        4
# 4      27        591          1               7                        1
# ...   ...        ...        ...             ...                      ...
# 1465   36        884          2            2061                        3
# 1466   39        613          1            2062                        4
# 1467   27        155          3            2064                        2
# 1468   49       1023          3            2065                        4
# 1469   34        628          3            2068                        2
#
#       HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# ...

# %% [markdown]
# <b><u>Milestone 3</u></b>
# <br>
# In Milestone 3, you will begin the process of selecting, building, and evaluating a model. You are required to train and evaluate <b>at least one model</b> in this milestone. Write step-by-step for performing each of these steps. You can use any methods/tools you think are most appropriate, but you should <b>explain/justify why you are selecting the model(s) and evaluation metric(s) you choose.</b> It is important to think about what type of model and metric makes sense for your problem. Again, do what makes the most sense for your project. <b>Write a short overview/conclusion of the insights gained from your model building/evaluation.</b>
# <br>
#
# It is important to note that these milestones are meant to keep you on track for the final project submission. At any point, you can pivot or modify your project as needed based on what you discover. These milestones are not final versions; they are drafts of the many steps you need to complete along the way.
# <br>
#
# As a reminder, Teams is a great place to discuss your project with your peers. Feel free to solicit feedback/input (without creating a group project!) and collaborate on your projects with your peers.
# <br>
#
# Each milestone will build on top of each other, so make sure you do not fall behind. Submit Milestones 1-3 together. I recommend building your project milestones in a Jupyter Notebook, building upon one another. However, make sure it is clear where each milestone begins and ends.
# <br>

# %% [markdown]
#     I would like to start off by saying that throughout this course I have learned these methods/tools: linear regression (4.2 exercise), lasso regression (4.2 exercise), logistic regression (5.2 exercise), support vector classifier (5.2 exercise), decision tree classifier (7.2 exercise), K Nearest Neighbor Classifier (9.2 exercise), and as well as Random Forest Classifier (9.2 exercise). As I have explored these various methods, I came to an understanding that my model does not apply to classification methods since the values for my target column varies based on numeric metrics on a scale from one to four. I would be using a linear regression to explore my dataset.

# %%
# Step 1: Split the data into a training and test set, where the “JobSatisfaction” column as the target.
from sklearn.model_selection import train_test_split

#df_modified_2_with_dummies
df_modified_2_with_dummies_filter = df_modified_2_with_dummies.drop(['JobSatisfaction'], axis=1)

features_train, features_test, target_train, target_test = train_test_split(df_modified_2_with_dummies_filter, df_modified_2_with_dummies.JobSatisfaction, test_size=0.2, random_state=0)

# %%
# Step 2: Process the model with the split dataset
from sklearn.linear_model import LinearRegression

# initalize the LinearRegression model
regression = LinearRegression()

# fit the training dataset to the linear regression model
model = regression.fit(features_train, target_train)

# print the accuracy of the model's training dataset
print(model.score(features_train, target_train))
# Out:
# 0.040905252285669436

# %%
# Repeat Steps 0-2: But instead by additionally dropping "EmployeeNumber" column as a suggested from the Professor 
df_modified_second = df.drop(['Department', 'DistanceFromHome', 'EmployeeCount', 'EmployeeNumber','MonthlyRate', 'Over18', 
                       'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear'], axis=1)
df_modified_second_2 = df_modified_second
df_modified_second_2_with_dummies = pd.get_dummies(df_modified_second_2, drop_first=True) 

#df_modified_second_2_with_dummies
df_modified_second_2_with_dummies_filter = df_modified_second_2_with_dummies.drop(['JobSatisfaction'], axis=1)

features_train_2, features_test_2, target_train_2, target_test_2 = train_test_split(df_modified_second_2_with_dummies_filter, df_modified_second_2_with_dummies.JobSatisfaction, test_size=0.2, random_state=0)


# initalize the LinearRegression model
regression_2 = LinearRegression()

# fit the training dataset to the linear regression model
model_2 = regression_2.fit(features_train_2, target_train_2)

# print the accuracy of the model's training dataset
print(model_2.score(features_train_2, target_train_2))
# Out:
# 0.038717596606364535

# %%
# Repeat Steps 0-2: But instead by not dropping any of the columns 
df_copy = df
#df_copy
df_copy_with_dummies = pd.get_dummies(df_copy, drop_first=True) 

df_copy_with_dummies_filter = df_copy_with_dummies.drop(['JobSatisfaction'], axis=1)

features_train_3, features_test_3, target_train_3, target_test_3 = train_test_split(df_copy_with_dummies_filter, df_copy_with_dummies.JobSatisfaction, test_size=0.2, random_state=0)


# initalize the LinearRegression model
regression_3 = LinearRegression()

# fit the training dataset to the linear regression model
model_3 = regression_3.fit(features_train_3, target_train_3)

# print the accuracy of the model's training dataset
print(model_3.score(features_train_3, target_train_3))
# Out:
# 0.045392198189057154

# %% [markdown]
# It appears initially that by dropping the columns I deem to see as unnecessary to have a better accuracy for my desire model resulted in the opposite effect. I proceed further by removing the previously dropped columns I had earlier to confirm my theory. The difference between initial and previous accuracy model came out to be about 0.0066 or 6.6 × $ 10^{-3} $.

# %% [markdown]
# <b><u>Milestone 4</u></b>
# <br>
# You have made it to the final week of the course and the time has come to submit your final project! Using your own judgment and based on the feedback you have received, update your project accordingly. Add any new code and/or analysis to your content from Milestones 1-3. Clearly note what content has been added since Milestone 3. Include this as part of your final project submission.
# <br>
#
# The primary final submission for the term project is <b>a minimum five-page project writeup</b>, e.g., MS Word or PDF file, summarizing the details of your project. Your final submission should include the following.
# <br>
#
# Introduction
# <br>
# - Introduce the problem
# - Justify why it is important/useful to solve this problem
# - How would you pitch this problem to a group of stakeholders to gain buy-in to proceed?
# - Explain where you obtained your data
# <br>
#
# Organized and detailed summary of Milestones 1-3
# <br>
# - EDA; include any visuals you think are important to your project
# - Data preparation
# - Model building and evaluation
#
# <br>
#
# Conclusion
# <br>
# - What does the analysis/model building tell you?
# - Is this model ready to be deployed?
# - What are your recommendations?
# - What are some of the potential challenges or additional opportunities that still need to be explored?
#
# <br>
#
# <b>To summarize,</b> you should submit the following <b>two items</b> for your term project final submissions:
# 1. All code, content, and analysis from Milestones 1-3 along with any updates
# 2. Project writeup described above
# <br>

# %% [markdown]
# <b>Feedback:</b> Dan, this looks pretty good, but I think you should try a classification model rather than a regression model as your data target is classes. You could even bin the data based on the satisfaction level as "not satisfied", "satisfied", and "highly satisfied", or something like that.

# %%
df_copy_again = df

# %%
# Define bins and labels
bins = [1, 2, 3, 4, 5]
labels = ['Low Satisfaction', 'Paritial Satisfaction', 'Satisfied', 'Highly Satisfied']

# Bin the column
df_copy_again['binned'] = pd.cut(df_copy_again['JobSatisfaction'], bins=bins, labels=labels, right=False)

# Create dummy variables (one-hot encoding)
binned_columns = pd.get_dummies(df_copy_again['binned'], prefix='bin')
#binned_columns = pd.get_dummies(df['binned'])
                                
# Concatenate with original DataFrame
df_copy_again = pd.concat([df_copy_again, binned_columns], axis=1)

# Drop the original binned column (optional)
df_copy_again = df_copy_again.drop('binned', axis=1)

# %%
df_copy_again
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# <b>Feedback Approach: </b> After careful consideration, I decided that binning the data separately for the JobSatisfaction column wouldn't be appropriate since it is my target variable I am targeting. However, I would do the latter approach by using a classification model and in this case I will be using Multinomial Logistic Regression for my data analysis.

# %%
# https://www.geeksforgeeks.org/understanding-logistic-regression/
#df.JobSatisfaction

df_modified_again = df.drop(['binned'], axis=1)

df_modified_again
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_modified_again_with_dummies = pd.get_dummies(df_modified_again, drop_first=True)

# %%
#df_modified_again_with_dummies

# %%
df_modified_again_with_dummies_filter = df_modified_again_with_dummies.drop(['JobSatisfaction'], axis=1)

features_train_again, features_test_again, target_train_again, target_test_again = train_test_split(df_modified_again_with_dummies_filter, df_modified_again_with_dummies.JobSatisfaction, test_size=0.2, random_state=0)

# %%
#target_test_again

# %%
from sklearn.linear_model import LogisticRegression

model_again = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)
#model.fit(X_train, y_train)
model_again.fit(features_train_again, target_train_again)
# Out:
# /Users/dandoan/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %%
#y_pred = model.predict(X_test)
target_prediction = model_again.predict(features_test_again)

# %%
from sklearn.metrics import accuracy_score, classification_report


#accuracy = accuracy_score(y_test, y_pred)
accuracy = accuracy_score(target_test_again, target_prediction)

print(f'Accuracy: {accuracy}')

print()
print()

#print(classification_report(y_test, y_pred))
print(classification_report(target_test_again, target_prediction))
# Out:
# Accuracy: 0.2789115646258503
#
#
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        61
#            2       0.00      0.00      0.00        51
#            3       0.30      0.32      0.31        94
#            4       0.29      0.59      0.39        88
#
#     accuracy                           0.28       294
#    macro avg       0.15      0.23      0.18       294
# weighted avg       0.18      0.28      0.22       294
# /Users/dandoan/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
